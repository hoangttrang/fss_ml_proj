# %% [markdown]
# # State Crash Data Raw Data to Input Data

# %% [markdown]
# This data was sourced from [Federal Motor Carrier Safety Administration](https://ai.fmcsa.dot.gov/CrashStatistics/?tab=Summary&type=&report_id=1&crash_type_id=4&datasource_id=1&time_period_id=2&report_date=2025&vehicle_type=1&state=AllStates&domicile=US&measure_id=1&operation_id=null) and reports data on all large truck and bus crashes between 2018 and 2025.
#
# The data was available for download as a .xlsx files so we uploaded it as a folder to the Local Filesystem and then copied it to GCS for persistent storage.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date, month, year, avg, count
from pyspark.sql.types import StructType, StructField, StringType
import os
import pandas as pd
from functools import reduce
from pyspark.sql import DataFrame
import re
from pyspark.sql.functions import input_file_name, regexp_extract, lit
import os
import glob
import os
from pyspark.sql.functions import lit, col, to_date, month
from pyspark.sql.functions import col, count, sum, when, isnan, mean, corr, month, year, desc
from pyspark.sql.types import IntegerType, DoubleType, FloatType, DateType

# %%
# Initialize Spark session
spark = SparkSession.builder \
    .appName("CSV Processing by Year") \
    .getOrCreate()

# %%
data_path = "/data/state_crash_data"

# %%
# Set paths
local_data_path = "/data/state_crash_data"
gcs_bucket_path = "gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data"

# %%
# Find all CSV files in the local directory and subdirectories
csv_files = glob.glob(f"{local_data_path}/**/*.csv", recursive=True)
print(f"Found {len(csv_files)} CSV files to upload")

# Upload each CSV file to GCS
for csv_file in csv_files:
    # Get the relative path to maintain directory structure
    relative_path = os.path.relpath(csv_file, local_data_path)
    # Construct the destination path
    destination = os.path.join(gcs_bucket_path, relative_path)
    # Upload the file
    print(f"Uploading {csv_file} to {destination}")
    # !gsutil cp {csv_file} {destination}

print("Upload complete!")
# Out:
# Found 150 CSV files to upload
# Uploading /data/state_crash_data/KY_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/KY_2025_crash.csv
# Copying file:///data/state_crash_data/KY_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][132.8 KiB/132.8 KiB]
# Operation completed over 1 objects/132.8 KiB.
# Uploading /data/state_crash_data/NY_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NY_2024_crash.csv
# Copying file:///data/state_crash_data/NY_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.4 MiB/  2.4 MiB]
# Operation completed over 1 objects/2.4 MiB.
# Uploading /data/state_crash_data/VA_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/VA_2025_crash.csv
# Copying file:///data/state_crash_data/VA_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][171.2 KiB/171.2 KiB]
# Operation completed over 1 objects/171.2 KiB.
# Uploading /data/state_crash_data/UT_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/UT_2025_crash.csv
# Copying file:///data/state_crash_data/UT_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 26.7 KiB/ 26.7 KiB]
# Operation completed over 1 objects/26.7 KiB.
# Uploading /data/state_crash_data/NE_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NE_2024_crash.csv
# Copying file:///data/state_crash_data/NE_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][601.4 KiB/601.4 KiB]
# Operation completed over 1 objects/601.4 KiB.
# Uploading /data/state_crash_data/NE_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NE_2025_crash.csv
# Copying file:///data/state_crash_data/NE_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 36.5 KiB/ 36.5 KiB]
# Operation completed over 1 objects/36.5 KiB.
# Uploading /data/state_crash_data/OK_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/OK_2024_crash.csv
# Copying file:///data/state_crash_data/OK_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.8 MiB/  1.8 MiB]
# Operation completed over 1 objects/1.8 MiB.
# Uploading /data/state_crash_data/OH_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/OH_2025_crash.csv
# Copying file:///data/state_crash_data/OH_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][245.6 KiB/245.6 KiB]
# Operation completed over 1 objects/245.6 KiB.
# Uploading /data/state_crash_data/PA_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/PA_2023_crash.csv
# Copying file:///data/state_crash_data/PA_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  4.2 MiB/  4.2 MiB]
# Operation completed over 1 objects/4.2 MiB.
# Uploading /data/state_crash_data/ND_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/ND_2023_crash.csv
# Copying file:///data/state_crash_data/ND_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][358.4 KiB/358.4 KiB]
# Operation completed over 1 objects/358.4 KiB.
# Uploading /data/state_crash_data/WV_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WV_2024_crash.csv
# Copying file:///data/state_crash_data/WV_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][467.9 KiB/467.9 KiB]
# Operation completed over 1 objects/467.9 KiB.
# Uploading /data/state_crash_data/GA_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/GA_2024_crash.csv
# Copying file:///data/state_crash_data/GA_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  5.4 MiB/  5.4 MiB]
# Operation completed over 1 objects/5.4 MiB.
# Uploading /data/state_crash_data/MT_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MT_2024_crash.csv
# Copying file:///data/state_crash_data/MT_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][358.4 KiB/358.4 KiB]
# Operation completed over 1 objects/358.4 KiB.
# Uploading /data/state_crash_data/WA_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WA_2025_crash.csv
# Copying file:///data/state_crash_data/WA_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 77.4 KiB/ 77.4 KiB]
# Operation completed over 1 objects/77.4 KiB.
# Uploading /data/state_crash_data/NV_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NV_2024_crash.csv
# Copying file:///data/state_crash_data/NV_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][525.4 KiB/525.4 KiB]
# Operation completed over 1 objects/525.4 KiB.
# Uploading /data/state_crash_data/OR_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/OR_2024_crash.csv
# Copying file:///data/state_crash_data/OR_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Uploading /data/state_crash_data/KS_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/KS_2024_crash.csv
# Copying file:///data/state_crash_data/KS_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][987.2 KiB/987.2 KiB]
# Operation completed over 1 objects/987.2 KiB.
# Uploading /data/state_crash_data/NH_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NH_2024_crash.csv
# Copying file:///data/state_crash_data/NH_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][240.9 KiB/240.9 KiB]
# Operation completed over 1 objects/240.9 KiB.
# Uploading /data/state_crash_data/WV_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WV_2023_crash.csv
# Copying file:///data/state_crash_data/WV_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][563.7 KiB/563.7 KiB]
# Operation completed over 1 objects/563.7 KiB.
# Uploading /data/state_crash_data/MI_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MI_2025_crash.csv
# Copying file:///data/state_crash_data/MI_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][105.8 KiB/105.8 KiB]
# Operation completed over 1 objects/105.8 KiB.
# Uploading /data/state_crash_data/MD_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MD_2025_crash.csv
# Copying file:///data/state_crash_data/MD_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.0 KiB/  1.0 KiB]
# Operation completed over 1 objects/1.0 KiB.
# Uploading /data/state_crash_data/ME_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/ME_2025_crash.csv
# Copying file:///data/state_crash_data/ME_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 31.4 KiB/ 31.4 KiB]
# Operation completed over 1 objects/31.4 KiB.
# Uploading /data/state_crash_data/RI_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/RI_2023_crash.csv
# Copying file:///data/state_crash_data/RI_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][ 97.2 KiB/ 97.2 KiB]
# Operation completed over 1 objects/97.2 KiB.
# Uploading /data/state_crash_data/NV_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NV_2025_crash.csv
# Copying file:///data/state_crash_data/NV_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 42.8 KiB/ 42.8 KiB]
# Operation completed over 1 objects/42.8 KiB.
# Uploading /data/state_crash_data/CA_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/CA_2023_crash.csv
# Copying file:///data/state_crash_data/CA_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  8.1 MiB/  8.1 MiB]
# Operation completed over 1 objects/8.1 MiB.
# Uploading /data/state_crash_data/KS_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/KS_2023_crash.csv
# Copying file:///data/state_crash_data/KS_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][ 1014 KiB/ 1014 KiB]
# Operation completed over 1 objects/1014.8 KiB.
# Uploading /data/state_crash_data/VA_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/VA_2023_crash.csv
# Copying file:///data/state_crash_data/VA_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.2 MiB/  3.2 MiB]
# Operation completed over 1 objects/3.2 MiB.
# Uploading /data/state_crash_data/FL_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/FL_2025_crash.csv
# Copying file:///data/state_crash_data/FL_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][259.6 KiB/259.6 KiB]
# Operation completed over 1 objects/259.6 KiB.
# Uploading /data/state_crash_data/WY_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WY_2023_crash.csv
# Copying file:///data/state_crash_data/WY_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][711.4 KiB/711.4 KiB]
# Operation completed over 1 objects/711.4 KiB.
# Uploading /data/state_crash_data/OR_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/OR_2025_crash.csv
# Copying file:///data/state_crash_data/OR_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 51.8 KiB/ 51.8 KiB]
# Operation completed over 1 objects/51.8 KiB.
# Uploading /data/state_crash_data/MO_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MO_2023_crash.csv
# Copying file:///data/state_crash_data/MO_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.9 MiB/  2.9 MiB]
# Operation completed over 1 objects/2.9 MiB.
# Uploading /data/state_crash_data/ND_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/ND_2024_crash.csv
# Copying file:///data/state_crash_data/ND_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][262.1 KiB/262.1 KiB]
# Operation completed over 1 objects/262.1 KiB.
# Uploading /data/state_crash_data/SD_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/SD_2025_crash.csv
# Copying file:///data/state_crash_data/SD_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.0 KiB/  2.0 KiB]
# Operation completed over 1 objects/2.0 KiB.
# Uploading /data/state_crash_data/SC_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/SC_2023_crash.csv
# Copying file:///data/state_crash_data/SC_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.8 MiB/  1.8 MiB]
# Operation completed over 1 objects/1.8 MiB.
# Uploading /data/state_crash_data/OH_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/OH_2024_crash.csv
# Copying file:///data/state_crash_data/OH_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.4 MiB/  3.4 MiB]
# Operation completed over 1 objects/3.4 MiB.
# Uploading /data/state_crash_data/CO_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/CO_2025_crash.csv
# Copying file:///data/state_crash_data/CO_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 28.5 KiB/ 28.5 KiB]
# Operation completed over 1 objects/28.5 KiB.
# Uploading /data/state_crash_data/LA_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/LA_2025_crash.csv
# Copying file:///data/state_crash_data/LA_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 87.1 KiB/ 87.1 KiB]
# Operation completed over 1 objects/87.1 KiB.
# Uploading /data/state_crash_data/NM_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NM_2023_crash.csv
# Copying file:///data/state_crash_data/NM_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][604.6 KiB/604.6 KiB]
# Operation completed over 1 objects/604.6 KiB.
# Uploading /data/state_crash_data/ID_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/ID_2024_crash.csv
# Copying file:///data/state_crash_data/ID_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][412.6 KiB/412.6 KiB]
# Operation completed over 1 objects/412.6 KiB.
# Uploading /data/state_crash_data/WI_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WI_2024_crash.csv
# Copying file:///data/state_crash_data/WI_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.4 MiB/  1.4 MiB]
# Operation completed over 1 objects/1.4 MiB.
# Uploading /data/state_crash_data/NJ_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NJ_2023_crash.csv
# Copying file:///data/state_crash_data/NJ_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.8 MiB/  1.8 MiB]
# Operation completed over 1 objects/1.8 MiB.
# Uploading /data/state_crash_data/IL_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/IL_2023_crash.csv
# Copying file:///data/state_crash_data/IL_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  4.0 MiB/  4.0 MiB]
# Operation completed over 1 objects/4.0 MiB.
# Uploading /data/state_crash_data/NY_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NY_2025_crash.csv
# Copying file:///data/state_crash_data/NY_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][132.6 KiB/132.6 KiB]
# Operation completed over 1 objects/132.6 KiB.
# Uploading /data/state_crash_data/MT_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MT_2025_crash.csv
# Copying file:///data/state_crash_data/MT_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 34.8 KiB/ 34.8 KiB]
# Operation completed over 1 objects/34.8 KiB.
# Uploading /data/state_crash_data/AL_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AL_2023_crash.csv
# Copying file:///data/state_crash_data/AL_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.0 MiB/  2.0 MiB]
# Operation completed over 1 objects/2.0 MiB.
# Uploading /data/state_crash_data/MI_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MI_2024_crash.csv
# Copying file:///data/state_crash_data/MI_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.4 MiB/  3.4 MiB]
# Operation completed over 1 objects/3.4 MiB.
# Uploading /data/state_crash_data/CA_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/CA_2025_crash.csv
# Copying file:///data/state_crash_data/CA_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  6.9 KiB/  6.9 KiB]
# Operation completed over 1 objects/6.9 KiB.
# Uploading /data/state_crash_data/HI_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/HI_2024_crash.csv
# Copying file:///data/state_crash_data/HI_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][117.9 KiB/117.9 KiB]
# Operation completed over 1 objects/117.9 KiB.
# Uploading /data/state_crash_data/GA_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/GA_2023_crash.csv
# Copying file:///data/state_crash_data/GA_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  5.3 MiB/  5.3 MiB]
# Operation completed over 1 objects/5.3 MiB.
# Uploading /data/state_crash_data/ND_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/ND_2025_crash.csv
# Copying file:///data/state_crash_data/ND_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.0 KiB/  1.0 KiB]
# Operation completed over 1 objects/1.0 KiB.
# Uploading /data/state_crash_data/DE_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/DE_2025_crash.csv
# Copying file:///data/state_crash_data/DE_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.0 KiB/  1.0 KiB]
# Operation completed over 1 objects/1.0 KiB.
# Uploading /data/state_crash_data/WI_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WI_2025_crash.csv
# Copying file:///data/state_crash_data/WI_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 85.7 KiB/ 85.7 KiB]
# Operation completed over 1 objects/85.7 KiB.
# Uploading /data/state_crash_data/VA_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/VA_2024_crash.csv
# Copying file:///data/state_crash_data/VA_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.2 MiB/  3.2 MiB]
# Operation completed over 1 objects/3.2 MiB.
# Uploading /data/state_crash_data/TN_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/TN_2023_crash.csv
# Copying file:///data/state_crash_data/TN_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.6 MiB/  2.6 MiB]
# Operation completed over 1 objects/2.6 MiB.
# Uploading /data/state_crash_data/AK_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AK_2024_crash.csv
# Copying file:///data/state_crash_data/AK_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][ 17.6 KiB/ 17.6 KiB]
# Operation completed over 1 objects/17.6 KiB.
# Uploading /data/state_crash_data/FL_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/FL_2024_crash.csv
# Copying file:///data/state_crash_data/FL_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  5.7 MiB/  5.7 MiB]
# Operation completed over 1 objects/5.7 MiB.
# Uploading /data/state_crash_data/SD_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/SD_2023_crash.csv
# Copying file:///data/state_crash_data/SD_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][287.0 KiB/287.0 KiB]
# Operation completed over 1 objects/287.0 KiB.
# Uploading /data/state_crash_data/TN_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/TN_2025_crash.csv
# Copying file:///data/state_crash_data/TN_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][187.4 KiB/187.4 KiB]
# Operation completed over 1 objects/187.4 KiB.
# Uploading /data/state_crash_data/MN_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MN_2024_crash.csv
# Copying file:///data/state_crash_data/MN_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Uploading /data/state_crash_data/AR_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AR_2023_crash.csv
# Copying file:///data/state_crash_data/AR_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.7 MiB/  1.7 MiB]
# Operation completed over 1 objects/1.7 MiB.
# Uploading /data/state_crash_data/MS_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MS_2023_crash.csv
# Copying file:///data/state_crash_data/MS_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.0 MiB/  1.0 MiB]
# Operation completed over 1 objects/1.0 MiB.
# Uploading /data/state_crash_data/NC_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NC_2025_crash.csv
# Copying file:///data/state_crash_data/NC_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][179.2 KiB/179.2 KiB]
# Operation completed over 1 objects/179.2 KiB.
# Uploading /data/state_crash_data/IA_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/IA_2023_crash.csv
# Copying file:///data/state_crash_data/IA_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Uploading /data/state_crash_data/SC_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/SC_2024_crash.csv
# Copying file:///data/state_crash_data/SC_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.8 MiB/  1.8 MiB]
# Operation completed over 1 objects/1.8 MiB.
# Uploading /data/state_crash_data/TX_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/TX_2025_crash.csv
# Copying file:///data/state_crash_data/TX_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][407.9 KiB/407.9 KiB]
# Operation completed over 1 objects/407.9 KiB.
# Uploading /data/state_crash_data/MI_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MI_2023_crash.csv
# Copying file:///data/state_crash_data/MI_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.4 MiB/  3.4 MiB]
# Operation completed over 1 objects/3.4 MiB.
# Uploading /data/state_crash_data/AK_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AK_2023_crash.csv
# Copying file:///data/state_crash_data/AK_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][ 29.8 KiB/ 29.8 KiB]
# Operation completed over 1 objects/29.8 KiB.
# Uploading /data/state_crash_data/CO_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/CO_2024_crash.csv
# Copying file:///data/state_crash_data/CO_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Uploading /data/state_crash_data/IL_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/IL_2025_crash.csv
# Copying file:///data/state_crash_data/IL_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][308.9 KiB/308.9 KiB]
# Operation completed over 1 objects/308.9 KiB.
# Uploading /data/state_crash_data/MA_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MA_2024_crash.csv
# Copying file:///data/state_crash_data/MA_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Uploading /data/state_crash_data/MD_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MD_2023_crash.csv
# Copying file:///data/state_crash_data/MD_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.2 MiB/  2.2 MiB]
# Operation completed over 1 objects/2.2 MiB.
# Uploading /data/state_crash_data/AZ_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AZ_2024_crash.csv
# Copying file:///data/state_crash_data/AZ_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.6 MiB/  1.6 MiB]
# Operation completed over 1 objects/1.6 MiB.
# Uploading /data/state_crash_data/TX_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/TX_2024_crash.csv
# Copying file:///data/state_crash_data/TX_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][ 10.8 MiB/ 10.8 MiB]
# Operation completed over 1 objects/10.8 MiB.
# Uploading /data/state_crash_data/IN_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/IN_2025_crash.csv
# Copying file:///data/state_crash_data/IN_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 17.9 KiB/ 17.9 KiB]
# Operation completed over 1 objects/17.9 KiB.
# Uploading /data/state_crash_data/DE_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/DE_2023_crash.csv
# Copying file:///data/state_crash_data/DE_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][366.3 KiB/366.3 KiB]
# Operation completed over 1 objects/366.3 KiB.
# Uploading /data/state_crash_data/MT_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MT_2023_crash.csv
# Copying file:///data/state_crash_data/MT_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][449.6 KiB/449.6 KiB]
# Operation completed over 1 objects/449.6 KiB.
# Uploading /data/state_crash_data/LA_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/LA_2024_crash.csv
# Copying file:///data/state_crash_data/LA_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.1 MiB/  2.1 MiB]
# Operation completed over 1 objects/2.1 MiB.
# Uploading /data/state_crash_data/OH_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/OH_2023_crash.csv
# Copying file:///data/state_crash_data/OH_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.3 MiB/  3.3 MiB]
# Operation completed over 1 objects/3.3 MiB.
# Uploading /data/state_crash_data/MA_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MA_2025_crash.csv
# Copying file:///data/state_crash_data/MA_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 48.8 KiB/ 48.8 KiB]
# Operation completed over 1 objects/48.8 KiB.
# Uploading /data/state_crash_data/VT_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/VT_2023_crash.csv
# Copying file:///data/state_crash_data/VT_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][ 89.9 KiB/ 89.9 KiB]
# Operation completed over 1 objects/89.9 KiB.
# Uploading /data/state_crash_data/NH_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NH_2025_crash.csv
# Copying file:///data/state_crash_data/NH_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  8.5 KiB/  8.5 KiB]
# Operation completed over 1 objects/8.5 KiB.
# Uploading /data/state_crash_data/HI_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/HI_2023_crash.csv
# Copying file:///data/state_crash_data/HI_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][111.5 KiB/111.5 KiB]
# Operation completed over 1 objects/111.5 KiB.
# Uploading /data/state_crash_data/MD_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MD_2024_crash.csv
# Copying file:///data/state_crash_data/MD_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][447.6 KiB/447.6 KiB]
# Operation completed over 1 objects/447.6 KiB.
# Uploading /data/state_crash_data/VT_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/VT_2024_crash.csv
# Copying file:///data/state_crash_data/VT_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][ 95.3 KiB/ 95.3 KiB]
# Operation completed over 1 objects/95.3 KiB.
# Uploading /data/state_crash_data/ID_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/ID_2025_crash.csv
# Copying file:///data/state_crash_data/ID_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  4.9 KiB/  4.9 KiB]
# Operation completed over 1 objects/4.9 KiB.
# Uploading /data/state_crash_data/OR_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/OR_2023_crash.csv
# Copying file:///data/state_crash_data/OR_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Uploading /data/state_crash_data/NM_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NM_2024_crash.csv
# Copying file:///data/state_crash_data/NM_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][502.0 KiB/502.0 KiB]
# Operation completed over 1 objects/502.0 KiB.
# Uploading /data/state_crash_data/AZ_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AZ_2025_crash.csv
# Copying file:///data/state_crash_data/AZ_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 74.9 KiB/ 74.9 KiB]
# Operation completed over 1 objects/74.9 KiB.
# Uploading /data/state_crash_data/OK_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/OK_2023_crash.csv
# Copying file:///data/state_crash_data/OK_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.4 MiB/  1.4 MiB]
# Operation completed over 1 objects/1.4 MiB.
# Uploading /data/state_crash_data/NM_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NM_2025_crash.csv
# Copying file:///data/state_crash_data/NM_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 20.0 KiB/ 20.0 KiB]
# Operation completed over 1 objects/20.0 KiB.
# Uploading /data/state_crash_data/NJ_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NJ_2024_crash.csv
# Copying file:///data/state_crash_data/NJ_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.3 MiB/  3.3 MiB]
# Operation completed over 1 objects/3.3 MiB.
# Uploading /data/state_crash_data/NC_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NC_2023_crash.csv
# Copying file:///data/state_crash_data/NC_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.7 MiB/  3.7 MiB]
# Operation completed over 1 objects/3.7 MiB.
# Uploading /data/state_crash_data/UT_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/UT_2023_crash.csv
# Copying file:///data/state_crash_data/UT_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][612.8 KiB/612.8 KiB]
# Operation completed over 1 objects/612.8 KiB.
# Uploading /data/state_crash_data/NH_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NH_2023_crash.csv
# Copying file:///data/state_crash_data/NH_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][256.2 KiB/256.2 KiB]
# Operation completed over 1 objects/256.2 KiB.
# Uploading /data/state_crash_data/TX_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/TX_2023_crash.csv
# Copying file:///data/state_crash_data/TX_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][ 11.3 MiB/ 11.3 MiB]
# Operation completed over 1 objects/11.3 MiB.
# Uploading /data/state_crash_data/IL_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/IL_2024_crash.csv
# Copying file:///data/state_crash_data/IL_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  4.3 MiB/  4.3 MiB]
# Operation completed over 1 objects/4.3 MiB.
# Uploading /data/state_crash_data/RI_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/RI_2025_crash.csv
# Copying file:///data/state_crash_data/RI_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  7.0 KiB/  7.0 KiB]
# Operation completed over 1 objects/7.0 KiB.
# Uploading /data/state_crash_data/IN_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/IN_2023_crash.csv
# Copying file:///data/state_crash_data/IN_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.9 MiB/  2.9 MiB]
# Operation completed over 1 objects/2.9 MiB.
# Uploading /data/state_crash_data/IA_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/IA_2025_crash.csv
# Copying file:///data/state_crash_data/IA_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 83.6 KiB/ 83.6 KiB]
# Operation completed over 1 objects/83.6 KiB.
# Uploading /data/state_crash_data/CT_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/CT_2024_crash.csv
# Copying file:///data/state_crash_data/CT_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][937.6 KiB/937.6 KiB]
# Operation completed over 1 objects/937.6 KiB.
# Uploading /data/state_crash_data/RI_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/RI_2024_crash.csv
# Copying file:///data/state_crash_data/RI_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][ 71.5 KiB/ 71.5 KiB]
# Operation completed over 1 objects/71.5 KiB.
# Uploading /data/state_crash_data/WA_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WA_2023_crash.csv
# Copying file:///data/state_crash_data/WA_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Uploading /data/state_crash_data/MS_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MS_2024_crash.csv
# Copying file:///data/state_crash_data/MS_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Uploading /data/state_crash_data/VT_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/VT_2025_crash.csv
# Copying file:///data/state_crash_data/VT_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.0 KiB/  2.0 KiB]
# Operation completed over 1 objects/2.0 KiB.
# Uploading /data/state_crash_data/ME_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/ME_2024_crash.csv
# Copying file:///data/state_crash_data/ME_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][440.7 KiB/440.7 KiB]
# Operation completed over 1 objects/440.7 KiB.
# Uploading /data/state_crash_data/WA_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WA_2024_crash.csv
# Copying file:///data/state_crash_data/WA_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Uploading /data/state_crash_data/NC_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NC_2024_crash.csv
# Copying file:///data/state_crash_data/NC_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.3 MiB/  3.3 MiB]
# Operation completed over 1 objects/3.3 MiB.
# Uploading /data/state_crash_data/HI_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/HI_2025_crash.csv
# Copying file:///data/state_crash_data/HI_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  5.1 KiB/  5.1 KiB]
# Operation completed over 1 objects/5.1 KiB.
# Uploading /data/state_crash_data/AR_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AR_2025_crash.csv
# Copying file:///data/state_crash_data/AR_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][100.8 KiB/100.8 KiB]
# Operation completed over 1 objects/100.8 KiB.
# Uploading /data/state_crash_data/KS_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/KS_2025_crash.csv
# Copying file:///data/state_crash_data/KS_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 56.5 KiB/ 56.5 KiB]
# Operation completed over 1 objects/56.5 KiB.
# Uploading /data/state_crash_data/OK_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/OK_2025_crash.csv
# Copying file:///data/state_crash_data/OK_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 99.5 KiB/ 99.5 KiB]
# Operation completed over 1 objects/99.5 KiB.
# Uploading /data/state_crash_data/SC_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/SC_2025_crash.csv
# Copying file:///data/state_crash_data/SC_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][159.2 KiB/159.2 KiB]
# Operation completed over 1 objects/159.2 KiB.
# Uploading /data/state_crash_data/NE_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NE_2023_crash.csv
# Copying file:///data/state_crash_data/NE_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][654.4 KiB/654.4 KiB]
# Operation completed over 1 objects/654.4 KiB.
# Uploading /data/state_crash_data/SD_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/SD_2024_crash.csv
# Copying file:///data/state_crash_data/SD_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][196.2 KiB/196.2 KiB]
# Operation completed over 1 objects/196.2 KiB.
# Uploading /data/state_crash_data/PA_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/PA_2024_crash.csv
# Copying file:///data/state_crash_data/PA_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  4.2 MiB/  4.2 MiB]
# Operation completed over 1 objects/4.2 MiB.
# Uploading /data/state_crash_data/AR_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AR_2024_crash.csv
# Copying file:///data/state_crash_data/AR_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.6 MiB/  1.6 MiB]
# Operation completed over 1 objects/1.6 MiB.
# Uploading /data/state_crash_data/MO_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MO_2024_crash.csv
# Copying file:///data/state_crash_data/MO_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.8 MiB/  2.8 MiB]
# Operation completed over 1 objects/2.8 MiB.
# Uploading /data/state_crash_data/WY_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WY_2025_crash.csv
# Copying file:///data/state_crash_data/WY_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 57.1 KiB/ 57.1 KiB]
# Operation completed over 1 objects/57.1 KiB.
# Uploading /data/state_crash_data/WV_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WV_2025_crash.csv
# Copying file:///data/state_crash_data/WV_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.0 KiB/  1.0 KiB]
# Operation completed over 1 objects/1.0 KiB.
# Uploading /data/state_crash_data/MN_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MN_2025_crash.csv
# Copying file:///data/state_crash_data/MN_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.0 KiB/  1.0 KiB]
# Operation completed over 1 objects/1.0 KiB.
# Uploading /data/state_crash_data/WI_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WI_2023_crash.csv
# Copying file:///data/state_crash_data/WI_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.5 MiB/  1.5 MiB]
# Operation completed over 1 objects/1.5 MiB.
# Uploading /data/state_crash_data/AZ_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AZ_2023_crash.csv
# Copying file:///data/state_crash_data/AZ_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.6 MiB/  1.6 MiB]
# Operation completed over 1 objects/1.6 MiB.
# Uploading /data/state_crash_data/IN_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/IN_2024_crash.csv
# Copying file:///data/state_crash_data/IN_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  3.0 MiB/  3.0 MiB]
# Operation completed over 1 objects/3.0 MiB.
# Uploading /data/state_crash_data/FL_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/FL_2023_crash.csv
# Copying file:///data/state_crash_data/FL_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  6.0 MiB/  6.0 MiB]
# Operation completed over 1 objects/6.0 MiB.
# Uploading /data/state_crash_data/MA_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MA_2023_crash.csv
# Copying file:///data/state_crash_data/MA_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Uploading /data/state_crash_data/AL_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AL_2024_crash.csv
# Copying file:///data/state_crash_data/AL_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.8 MiB/  1.8 MiB]
# Operation completed over 1 objects/1.8 MiB.
# Uploading /data/state_crash_data/ID_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/ID_2023_crash.csv
# Copying file:///data/state_crash_data/ID_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][423.0 KiB/423.0 KiB]
# Operation completed over 1 objects/423.0 KiB.
# Uploading /data/state_crash_data/MS_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MS_2025_crash.csv
# Copying file:///data/state_crash_data/MS_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 47.5 KiB/ 47.5 KiB]
# Operation completed over 1 objects/47.5 KiB.
# Uploading /data/state_crash_data/IA_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/IA_2024_crash.csv
# Copying file:///data/state_crash_data/IA_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Uploading /data/state_crash_data/ME_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/ME_2023_crash.csv
# Copying file:///data/state_crash_data/ME_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][452.3 KiB/452.3 KiB]
# Operation completed over 1 objects/452.3 KiB.
# Uploading /data/state_crash_data/MN_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MN_2023_crash.csv
# Copying file:///data/state_crash_data/MN_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.4 MiB/  1.4 MiB]
# Operation completed over 1 objects/1.4 MiB.
# Uploading /data/state_crash_data/WY_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/WY_2024_crash.csv
# Copying file:///data/state_crash_data/WY_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][575.8 KiB/575.8 KiB]
# Operation completed over 1 objects/575.8 KiB.
# Uploading /data/state_crash_data/CT_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/CT_2023_crash.csv
# Copying file:///data/state_crash_data/CT_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][ 1014 KiB/ 1014 KiB]
# Operation completed over 1 objects/1014.6 KiB.
# Uploading /data/state_crash_data/CO_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/CO_2023_crash.csv
# Copying file:///data/state_crash_data/CO_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Uploading /data/state_crash_data/PA_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/PA_2025_crash.csv
# Copying file:///data/state_crash_data/PA_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][107.4 KiB/107.4 KiB]
# Operation completed over 1 objects/107.4 KiB.
# Uploading /data/state_crash_data/GA_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/GA_2025_crash.csv
# Copying file:///data/state_crash_data/GA_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 32.4 KiB/ 32.4 KiB]
# Operation completed over 1 objects/32.4 KiB.
# Uploading /data/state_crash_data/UT_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/UT_2024_crash.csv
# Copying file:///data/state_crash_data/UT_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][546.3 KiB/546.3 KiB]
# Operation completed over 1 objects/546.3 KiB.
# Uploading /data/state_crash_data/NY_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NY_2023_crash.csv
# Copying file:///data/state_crash_data/NY_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.5 MiB/  2.5 MiB]
# Operation completed over 1 objects/2.5 MiB.
# Uploading /data/state_crash_data/TN_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/TN_2024_crash.csv
# Copying file:///data/state_crash_data/TN_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.4 MiB/  2.4 MiB]
# Operation completed over 1 objects/2.4 MiB.
# Uploading /data/state_crash_data/CA_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/CA_2024_crash.csv
# Copying file:///data/state_crash_data/CA_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  7.4 MiB/  7.4 MiB]
# Operation completed over 1 objects/7.4 MiB.
# Uploading /data/state_crash_data/CT_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/CT_2025_crash.csv
# Copying file:///data/state_crash_data/CT_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][ 45.6 KiB/ 45.6 KiB]
# Operation completed over 1 objects/45.6 KiB.
# Uploading /data/state_crash_data/DE_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/DE_2024_crash.csv
# Copying file:///data/state_crash_data/DE_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][355.4 KiB/355.4 KiB]
# Operation completed over 1 objects/355.4 KiB.
# Uploading /data/state_crash_data/AL_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AL_2025_crash.csv
# Copying file:///data/state_crash_data/AL_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][122.8 KiB/122.8 KiB]
# Operation completed over 1 objects/122.8 KiB.
# Uploading /data/state_crash_data/NJ_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NJ_2025_crash.csv
# Copying file:///data/state_crash_data/NJ_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.0 KiB/  1.0 KiB]
# Operation completed over 1 objects/1.0 KiB.
# Uploading /data/state_crash_data/MO_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/MO_2025_crash.csv
# Copying file:///data/state_crash_data/MO_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][130.2 KiB/130.2 KiB]
# Operation completed over 1 objects/130.2 KiB.
# Uploading /data/state_crash_data/KY_2024_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/KY_2024_crash.csv
# Copying file:///data/state_crash_data/KY_2024_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.7 MiB/  1.7 MiB]
# Operation completed over 1 objects/1.7 MiB.
# Uploading /data/state_crash_data/LA_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/LA_2023_crash.csv
# Copying file:///data/state_crash_data/LA_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  2.1 MiB/  2.1 MiB]
# Operation completed over 1 objects/2.1 MiB.
# Uploading /data/state_crash_data/AK_2025_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/AK_2025_crash.csv
# Copying file:///data/state_crash_data/AK_2025_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.6 KiB/  1.6 KiB]
# Operation completed over 1 objects/1.6 KiB.
# Uploading /data/state_crash_data/KY_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/KY_2023_crash.csv
# Copying file:///data/state_crash_data/KY_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][  1.8 MiB/  1.8 MiB]
# Operation completed over 1 objects/1.8 MiB.
# Uploading /data/state_crash_data/NV_2023_crash.csv to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/NV_2023_crash.csv
# Copying file:///data/state_crash_data/NV_2023_crash.csv [Content-Type=text/csv]...
# / [1 files][415.1 KiB/415.1 KiB]
# Operation completed over 1 objects/415.1 KiB.
# Upload complete!

# %%
# Create the local directory structure
local_dir = f"{local_data_path}/yearly_state_crash_data"
os.makedirs(local_dir, exist_ok=True)

# %%
def process_csv_files(local_data_path, gcs_bucket_path):
    # Find all CSV files using Python's glob
    csv_files = glob.glob(f"{local_data_path}/**/*.csv", recursive=True)
    print(f"Found {len(csv_files)} CSV files")
    
    # Group files by year
    files_by_year = {}
    for file_path in csv_files:
        # Extract year from filename or path
        match = re.search(r'(\d{4})', os.path.basename(file_path))
        if match:
            year = match.group(1)
            if year not in files_by_year:
                files_by_year[year] = []
            files_by_year[year].append(file_path)
    
    # Process each year's files
    for year, file_list in files_by_year.items():
        print(f"Processing {len(file_list)} files for year {year}")
        
        # Create empty list to store dataframes
        dfs = []
        
        # Read and concatenate all files for this year using pandas
        for file_path in file_list:
            try:
                # Read CSV file with pandas
                df = pd.read_csv(file_path)
                # Add source filename as a column
                df['source_file'] = os.path.basename(file_path)
                # Append to list
                dfs.append(df)
                print(f"  Added {file_path} with {len(df)} rows")
            except Exception as e:
                print(f"  Error reading {file_path}: {e}")
        
        if dfs:
            # Concatenate all dataframes for this year
            combined_df = pd.concat(dfs, ignore_index=True)
            print(f"  Created combined dataset with {len(combined_df)} rows")
            
            # Define output paths
            output_dir = f"{local_data_path}/yearly_state_crash_data"
            local_output_path = f"{output_dir}/state_crash_data_{year}.csv"
            gcs_output_path = f"{gcs_bucket_path}/yearly_state_crash_data/state_crash_data_{year}.csv"
            
            # Create directory if it doesn't exist
            os.makedirs(output_dir, exist_ok=True)
            
            # Save locally using pandas
            combined_df.to_csv(local_output_path, index=False)
            print(f"  Saved to {local_output_path}")
            
            # Upload to GCS
            os.system(f"gsutil cp {local_output_path} {gcs_output_path}")
            print(f"  Uploaded to {gcs_output_path}")
        else:
            print(f"  No valid files found for year {year}")
    
    print("Processing complete!")

# Call the function with your paths

# %%
process_csv_files(local_data_path, gcs_bucket_path)
# Out:
# Found 150 CSV files
# Processing 50 files for year 2025
#   Added /data/state_crash_data/KY_2025_crash.csv with 240 rows
#   Added /data/state_crash_data/VA_2025_crash.csv with 309 rows
#   Added /data/state_crash_data/UT_2025_crash.csv with 49 rows
#   Added /data/state_crash_data/NE_2025_crash.csv with 67 rows
#   Added /data/state_crash_data/OH_2025_crash.csv with 460 rows
#   Added /data/state_crash_data/WA_2025_crash.csv with 138 rows
#   Added /data/state_crash_data/MI_2025_crash.csv with 193 rows
#   Added /data/state_crash_data/MD_2025_crash.csv with 0 rows
#   Added /data/state_crash_data/ME_2025_crash.csv with 55 rows
#   Added /data/state_crash_data/NV_2025_crash.csv with 78 rows
#   Added /data/state_crash_data/FL_2025_crash.csv with 506 rows
#   Added /data/state_crash_data/OR_2025_crash.csv with 90 rows
#   Added /data/state_crash_data/SD_2025_crash.csv with 2 rows
#   Added /data/state_crash_data/CO_2025_crash.csv with 51 rows
#   Added /data/state_crash_data/LA_2025_crash.csv with 160 rows
#   Added /data/state_crash_data/NY_2025_crash.csv with 254 rows
#   Added /data/state_crash_data/MT_2025_crash.csv with 63 rows
#   Added /data/state_crash_data/CA_2025_crash.csv with 10 rows
#   Added /data/state_crash_data/ND_2025_crash.csv with 0 rows
#   Added /data/state_crash_data/DE_2025_crash.csv with 0 rows
#   Added /data/state_crash_data/WI_2025_crash.csv with 153 rows
#   Added /data/state_crash_data/TN_2025_crash.csv with 349 rows
#   Added /data/state_crash_data/NC_2025_crash.csv with 323 rows
#   Added /data/state_crash_data/TX_2025_crash.csv with 793 rows
#   Added /data/state_crash_data/IL_2025_crash.csv with 573 rows
#   Added /data/state_crash_data/IN_2025_crash.csv with 33 rows
#   Added /data/state_crash_data/MA_2025_crash.csv with 84 rows
#   Added /data/state_crash_data/NH_2025_crash.csv with 13 rows
#   Added /data/state_crash_data/ID_2025_crash.csv with 7 rows
#   Added /data/state_crash_data/AZ_2025_crash.csv with 131 rows
#   Added /data/state_crash_data/NM_2025_crash.csv with 34 rows
#   Added /data/state_crash_data/RI_2025_crash.csv with 11 rows
#   Added /data/state_crash_data/IA_2025_crash.csv with 153 rows
#   Added /data/state_crash_data/VT_2025_crash.csv with 2 rows
#   Added /data/state_crash_data/HI_2025_crash.csv with 7 rows
#   Added /data/state_crash_data/AR_2025_crash.csv with 181 rows
#   Added /data/state_crash_data/KS_2025_crash.csv with 106 rows
#   Added /data/state_crash_data/OK_2025_crash.csv with 178 rows
#   Added /data/state_crash_data/SC_2025_crash.csv with 298 rows
#   Added /data/state_crash_data/WY_2025_crash.csv with 103 rows
#   Added /data/state_crash_data/WV_2025_crash.csv with 0 rows
#   Added /data/state_crash_data/MN_2025_crash.csv with 0 rows
#   Added /data/state_crash_data/MS_2025_crash.csv with 88 rows
#   Added /data/state_crash_data/PA_2025_crash.csv with 199 rows
#   Added /data/state_crash_data/GA_2025_crash.csv with 56 rows
#   Added /data/state_crash_data/CT_2025_crash.csv with 80 rows
#   Added /data/state_crash_data/AL_2025_crash.csv with 228 rows
#   Added /data/state_crash_data/NJ_2025_crash.csv with 0 rows
#   Added /data/state_crash_data/MO_2025_crash.csv with 253 rows
#   Added /data/state_crash_data/AK_2025_crash.csv with 1 rows
#   Created combined dataset with 7162 rows
#   Saved to /data/state_crash_data/yearly_state_crash_data/state_crash_data_2025.csv
#   Uploaded to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/yearly_state_crash_data/state_crash_data_2025.csv
# Processing 50 files for year 2024
#   Added /data/state_crash_data/NY_2024_crash.csv with 4783 rows
#   Added /data/state_crash_data/NE_2024_crash.csv with 1129 rows
#   Added /data/state_crash_data/OK_2024_crash.csv with 3268 rows
#   Added /data/state_crash_data/WV_2024_crash.csv with 865 rows
#   Added /data/state_crash_data/GA_2024_crash.csv with 9883 rows
#   Added /data/state_crash_data/MT_2024_crash.csv with 671 rows
#   Added /data/state_crash_data/NV_2024_crash.csv with 982 rows
#   Added /data/state_crash_data/OR_2024_crash.csv with 2027 rows
#   Added /data/state_crash_data/KS_2024_crash.csv with 1851 rows
#   Added /data/state_crash_data/NH_2024_crash.csv with 428 rows
#   Added /data/state_crash_data/ND_2024_crash.csv with 493 rows
#   Added /data/state_crash_data/OH_2024_crash.csv with 6456 rows
#   Added /data/state_crash_data/ID_2024_crash.csv with 751 rows
#   Added /data/state_crash_data/WI_2024_crash.csv with 2618 rows
#   Added /data/state_crash_data/MI_2024_crash.csv with 6248 rows
#   Added /data/state_crash_data/HI_2024_crash.csv with 197 rows
#   Added /data/state_crash_data/VA_2024_crash.csv with 5960 rows
#   Added /data/state_crash_data/AK_2024_crash.csv with 29 rows
#   Added /data/state_crash_data/FL_2024_crash.csv with 10510 rows
#   Added /data/state_crash_data/MN_2024_crash.csv with 2222 rows
#   Added /data/state_crash_data/SC_2024_crash.csv with 3486 rows
#   Added /data/state_crash_data/CO_2024_crash.csv with 2071 rows
#   Added /data/state_crash_data/MA_2024_crash.csv with 2135 rows
#   Added /data/state_crash_data/AZ_2024_crash.csv with 2953 rows
#   Added /data/state_crash_data/TX_2024_crash.csv with 21648 rows
#   Added /data/state_crash_data/LA_2024_crash.csv with 4075 rows
#   Added /data/state_crash_data/MD_2024_crash.csv with 780 rows
#   Added /data/state_crash_data/VT_2024_crash.csv with 184 rows
#   Added /data/state_crash_data/NM_2024_crash.csv with 895 rows
#   Added /data/state_crash_data/NJ_2024_crash.csv with 5990 rows
#   Added /data/state_crash_data/IL_2024_crash.csv with 8011 rows
#   Added /data/state_crash_data/CT_2024_crash.csv with 1699 rows
#   Added /data/state_crash_data/RI_2024_crash.csv with 132 rows
#   Added /data/state_crash_data/MS_2024_crash.csv with 2143 rows
#   Added /data/state_crash_data/ME_2024_crash.csv with 808 rows
#   Added /data/state_crash_data/WA_2024_crash.csv with 2269 rows
#   Added /data/state_crash_data/NC_2024_crash.csv with 6131 rows
#   Added /data/state_crash_data/SD_2024_crash.csv with 385 rows
#   Added /data/state_crash_data/PA_2024_crash.csv with 8145 rows
#   Added /data/state_crash_data/AR_2024_crash.csv with 2942 rows
#   Added /data/state_crash_data/MO_2024_crash.csv with 5635 rows
#   Added /data/state_crash_data/IN_2024_crash.csv with 5889 rows
#   Added /data/state_crash_data/AL_2024_crash.csv with 3552 rows
#   Added /data/state_crash_data/IA_2024_crash.csv with 2349 rows
#   Added /data/state_crash_data/WY_2024_crash.csv with 1043 rows
#   Added /data/state_crash_data/UT_2024_crash.csv with 1041 rows
#   Added /data/state_crash_data/TN_2024_crash.csv with 4444 rows
#   Added /data/state_crash_data/CA_2024_crash.csv with 12996 rows
#   Added /data/state_crash_data/DE_2024_crash.csv with 620 rows
#   Added /data/state_crash_data/KY_2024_crash.csv with 3121 rows
#   Created combined dataset with 178943 rows
#   Saved to /data/state_crash_data/yearly_state_crash_data/state_crash_data_2024.csv
#   Uploaded to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/yearly_state_crash_data/state_crash_data_2024.csv
# Processing 50 files for year 2023
#   Added /data/state_crash_data/PA_2023_crash.csv with 8136 rows
#   Added /data/state_crash_data/ND_2023_crash.csv with 678 rows
#   Added /data/state_crash_data/WV_2023_crash.csv with 1043 rows
#   Added /data/state_crash_data/RI_2023_crash.csv with 186 rows
#   Added /data/state_crash_data/CA_2023_crash.csv with 14135 rows
#   Added /data/state_crash_data/KS_2023_crash.csv with 1901 rows
#   Added /data/state_crash_data/VA_2023_crash.csv with 6023 rows
#   Added /data/state_crash_data/WY_2023_crash.csv with 1292 rows
#   Added /data/state_crash_data/MO_2023_crash.csv with 5853 rows
#   Added /data/state_crash_data/SC_2023_crash.csv with 3469 rows
#   Added /data/state_crash_data/NM_2023_crash.csv with 1077 rows
#   Added /data/state_crash_data/NJ_2023_crash.csv with 3276 rows
#   Added /data/state_crash_data/IL_2023_crash.csv with 7576 rows
#   Added /data/state_crash_data/AL_2023_crash.csv with 3792 rows
#   Added /data/state_crash_data/GA_2023_crash.csv with 9597 rows
#   Added /data/state_crash_data/TN_2023_crash.csv with 4772 rows
#   Added /data/state_crash_data/SD_2023_crash.csv with 566 rows
#   Added /data/state_crash_data/AR_2023_crash.csv with 3208 rows
#   Added /data/state_crash_data/MS_2023_crash.csv with 2002 rows
#   Added /data/state_crash_data/IA_2023_crash.csv with 2299 rows
#   Added /data/state_crash_data/MI_2023_crash.csv with 6230 rows
#   Added /data/state_crash_data/AK_2023_crash.csv with 50 rows
#   Added /data/state_crash_data/MD_2023_crash.csv with 4153 rows
#   Added /data/state_crash_data/DE_2023_crash.csv with 638 rows
#   Added /data/state_crash_data/MT_2023_crash.csv with 838 rows
#   Added /data/state_crash_data/OH_2023_crash.csv with 6369 rows
#   Added /data/state_crash_data/VT_2023_crash.csv with 173 rows
#   Added /data/state_crash_data/HI_2023_crash.csv with 187 rows
#   Added /data/state_crash_data/OR_2023_crash.csv with 2015 rows
#   Added /data/state_crash_data/OK_2023_crash.csv with 2691 rows
#   Added /data/state_crash_data/NC_2023_crash.csv with 6882 rows
#   Added /data/state_crash_data/UT_2023_crash.csv with 1158 rows
#   Added /data/state_crash_data/NH_2023_crash.csv with 452 rows
#   Added /data/state_crash_data/TX_2023_crash.csv with 22628 rows
#   Added /data/state_crash_data/IN_2023_crash.csv with 5747 rows
#   Added /data/state_crash_data/WA_2023_crash.csv with 2265 rows
#   Added /data/state_crash_data/NE_2023_crash.csv with 1218 rows
#   Added /data/state_crash_data/WI_2023_crash.csv with 2730 rows
#   Added /data/state_crash_data/AZ_2023_crash.csv with 3041 rows
#   Added /data/state_crash_data/FL_2023_crash.csv with 10929 rows
#   Added /data/state_crash_data/MA_2023_crash.csv with 2057 rows
#   Added /data/state_crash_data/ID_2023_crash.csv with 775 rows
#   Added /data/state_crash_data/ME_2023_crash.csv with 819 rows
#   Added /data/state_crash_data/MN_2023_crash.csv with 2483 rows
#   Added /data/state_crash_data/CT_2023_crash.csv with 1847 rows
#   Added /data/state_crash_data/CO_2023_crash.csv with 2022 rows
#   Added /data/state_crash_data/NY_2023_crash.csv with 4969 rows
#   Added /data/state_crash_data/LA_2023_crash.csv with 3937 rows
#   Added /data/state_crash_data/KY_2023_crash.csv with 3332 rows
#   Added /data/state_crash_data/NV_2023_crash.csv with 786 rows
#   Created combined dataset with 184302 rows
#   Saved to /data/state_crash_data/yearly_state_crash_data/state_crash_data_2023.csv
#   Uploaded to gs://ds5460-arvelo-bucket0311/notebooks/jupyter/state_crash_data/yearly_state_crash_data/state_crash_data_2023.csv
# Processing complete!
